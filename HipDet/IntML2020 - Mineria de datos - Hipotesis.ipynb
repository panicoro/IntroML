# %% [markdown]
# <center>
# <img src="images/ods_stickers.jpg" />
#
# # Introducción al Machine Learning 2020
#
# Basado en material de  [Yury Kashnitsky](https://yorko.github.io). Traducido y editado al español por [Ana Georgina Flesia](https://www.linkedin.com/in/georginaflesia/). Este material esta sujeto a los términos y condiciones de la licencia  [Creative Commons CC BY-NC-SA 4.0](https://creativecommons.org/licenses/by-nc-sa/4.0/). Se permite el uso irrestricto para todo propósito no comercial.

# %% [markdown]
# ##  Minería de datos- Hipótesis

# %% [markdown]
# ### Ejercicio 1- En un consultorio oftalmológico la secretaria entrega a cada paciente la siguiente ficha, antes ser atendido, para que sea completada por el profesional:

# %% [markdown]
# ________________________________________
#
#     Paciente      (Nombre y Apellido)
#
#     Edad          (años)
#
#     Prescripción  (miopía-hipermetropía)
#
#     Astigmatismo  (si/no)
#
#     Lagrimeo      (normal/reducido)
#
# ________________________________________
#
#
# En cada turno de trabajo se atienden seis pacientes y a continuacion se presentan las fichas completadas por el oculista adecuadamente anonimizadas

# %% [raw]
#     Primer turno
#     --------------------------------------------------------------------------------------------------------------
#     paciente     | 01       | 02     | 03            | 04     | 05            | 06     |
#     --------------------------------------------------------------------------------------------------------------
#     edad         | 22       | 71     | 41            | 32     | 68            | 72     |
#     prescripción | miopía   | miopía | hipermetropía | miopía | hipermetropía | miopía |
#     astigmatismo | no       | sí     | no            | sí     | sí            | no     |
#     lagrimeo     | reducido | normal | reducido      | normal | reducido      | normal |
#
#     --------------------------------------------------------------------------------------------------------------
#
#
#     Segundo Turno
#     --------------------------------------------------------------------------------------------------------------
#     paciente     | 07            | 08       | 09       | 10     | 11            | 12     |
#     --------------------------------------------------------------------------------------------------------------
#     edad         | 62            | 42       | 38       | 43     | 28            | 37     |
#     prescripción | hipermetropía | miopía   | miopía   | miopía | hipermetropía | miopía |
#     astigmatismo | sí            | sí       | no       | no     | sí            | sí     |
#     lagrimeo     | normal        | reducido | reducido | normal | normal        | normal |
#
#     --------------------------------------------------------------------------------------------------------------
#
#
#     Tercer turno
#     --------------------------------------------------------------------------------------------------------------
#     paciente     | 13            | 14            | 15            | 16       | 17       | 18            |
#     --------------------------------------------------------------------------------------------------------------
#     edad         | 45            | 37            | 68            | 18       | 51       | 15            |
#     prescripción | hipermetropía | hipermetropía | hipermetropía | miopía   | miopía   | hipermetropía |
#     astigmatismo | sí            | no            | no            | sí       | no       | no            |
#     lagrimeo     | normal        | normal        | normal        | reducido | reducido | normal        |
#
#     --------------------------------------------------------------------------------------------------------------
#
#
#     Cuarto turno
#     --------------------------------------------------------------------------------------------------------------
#     paciente     | 19       & 20     & 21            & 22            & 23            & 24
#     --------------------------------------------------------------------------------------------------------------
#     edad         | 63       | 30     | 74            | 44            | 15            | 17            |
#     prescripción | miopía   | miopía | hipermetropía | hipermetropía | hipermetropía | hipermetropía |
#     astigmatismo | sí       | no     | no            | sí            | no            | sí            |
#     lagrimeo     | reducido | normal | reducido      | reducido      | reducido      | reducido      |

# %% [markdown]
# Una vez completada la ficha, los pacientes se dirigen luego al consultorio del contactólogo para que
# les recomienden o no el uso de lentes de contacto. Al final del dia el resumen de recomendaciones
# se recopila en la siguiente tabla:

# %% [raw]
#     paciente | recomendación | paciente | recomendación |paciente | recomendación |
#     -------------------------------------------------------------------------------
#
#     01       | nada          |  09      | nada          | 17      | nada          |
#     02       | duras         |  10      | blandas       | 18      | blandas       |
#     03       | nada          |  11      | nada          | 19      | nada          |
#     04       | duras         |  12      | duras         | 20      | blandas       |
#     05       | nada          |  13      | nada          | 21      | nada          |
#     06       | blandas       |  14      | blandas       | 22      | nada          |
#     07       | nada          |  15      | blandas       | 23      | nada          |
#     08       | nada          |  16      | nada          | 24      | nada          |

# %% [markdown]
# ### A): Elaborar una pregunta adecuada sobre los datos para formular un problema de aprendizaje automatico basado en la recomendacion del contactologo.

# %% [markdown]
# Dadas las características clínicas de un paciente estamos interesados en predecir si usará o no lentes de conctacto, y en caso de tener que usarlos de cúal tipo serán (blandos o duros).
#
# La pregunta sería:
#
# * ¿El paciente cuya **edad** es <span style='color:blue'> a </span>, con **prescripción** de (<span style='color:blue'>miopía/hipermetropía</span>), (<span style='color:blue'>con/sin</span>)  **astigmatismo** y con **lagrimeo** (<span style='color:blue'>reducido/normal</span>) debe usar lentes de contacto blandos o duros o no debe usarlos?

# %% [markdown]
# ### B): Señalar los problemas que tienen las tablas recolectadas en el consultorio para abordar el problema de aprendizaje supervisado.

# %% [markdown]
# Para el aprendizaje supervisado es importante tener un conjunto de **ejemplos de entrenamiento** (*training examples*) como punto inicial. En cada ejemplo de entrenamiento debemos tener una instancia $x$ con ciertos valores en las variables junto con el valor del concepto objetivo $c(x)$. El valor de $c(x)$ puede ser $1$ ó $0$, lo cual nos define a los ejemplos *positivos* o *negativos*, respectivamente.
#
# Si queremos usar la informacion en las tablas para generar el un conjunto de ejemplos de entrenamientos, debemos organizar los datos de ese manera. Los atributos (*edad*, *prescripción*, *astigmatismo*, *lagrimeo*) están claros junto a sus valores, pero no tenemos bien definido el concepto asociado. En los datos propiciados por el contactólogo tenemos la columna *recomendación* que toma estos valores: *nada, duras, blandas*. Es a partir de esa columna que se deben definirse el concepto.
#
# Mirando la pregunta del punto anterior, es claro que no hay un único concepto: se pueden definir dos conceptos diferentes *UsaLentesDuras* y *UsaLentesBlandas*. Los valores de esos conceptos pueden establecerse de esta manera:
#
# * $UsaLentesDuras(x) = 1$ si *recomendación* es "dura"; $0$ si es "nada" o "blanda".
# * $UsaLentesBlandas(x) = 1$ si *recomendación* es "blanda"; $0$ si es "nada" o "blanda".

# %% [markdown]
# ### C): A partir de la informacion disponible, elaborar un esquema apropiado para disponer los datos en una tabla util para mineria. Identificar las caracteristicas (variables) y su tipo de datos y declarar cual es la clase y sus valores para el problema de clasificacion.
#
# <span style="color:red">DUDA ¿Qué es la clase?  ¿Es el concepto? </span>

# %% [markdown]
# Siguiendo la idea del punto anterior el esquema de la tabla deberá incluir las siguientes columnas:
#
# |  Column name  | Description | Value Type |
# |---         |---       |---
# | **Age** | Patient age | Numerical |
# | **Prescription** | Patient diagnosis (Myopia/Hyperopia) | String, "HY"/"MY"|
# | **Astigmatism** | Presence of astigmatism | String, "Yes"/"No" |
# | **Tearing** |  Amount of tearing (Normal/Reduce) | String, "Normal"/"Reduced" |
# |**Recomedation**| The indication of the contactologist | String, "None"/"Hard"/"Soft" |
# | **HardLenses**| If the patient must use hard contact lenses |  Numerical,  0/1 |
# | **SoftLenses**| If the patient must use soft contact lenses |  Numerical, 0/1 |
#
# Los valores para los conceptos (*HardLenses*, *SoftLenses*) se establecerán siguiendo la regla dada en el punto anterior:
#
# * $HardLenses(x) = 1$ if *Recomendation* = "Hard" else  $0$.
# * $SoftLenses(x) = 1$ if *Recomendation* = "Soft" else  $0$.
#
# Los valores de las demás variables se corresponden con los que están en la tabla; para miopía usamos la sigla MY y para hipermetropía, HY.

# %% [markdown]
# ### D): Calcular el numero total de instancias posibles, suponiendo que la posible edad de un paciente esta en el intervalo que incluye los valores 10 y 100.

# %% [markdown]
# Dado que el atributo *edad* tiene 91 valores posibles y *prescripción*, *astigmatismo* y *lagrimero*  tienen 2 valores posibles cada uno; si agregamos el símbolo $?$ para cada atributo y luego contamos la posible existencia del símbolo $\emptyset$ para algún atributo, entonces tendremos un total de $1 + (91 \times 3 \times 3 \times 3) = 2458$ instancias posibles.

# %% [markdown]
# ### E): Construir la tabla de mineria con los ejemplos dados a partir del esquema formulado, dejando la clase en la ultima columna.

# %% [markdown]
# <span style="color:red"> DUDA: a que se refera con clase... sera conceptos... / otra la tabla en markdown o python?? </span>
#
# |**# example**|  **Age**  | **Prescription** | **Astigmatism** | **Tearing** | **Recomendation** | **HardLenses** | **SoftLenses**
# |---|---|---|---|---|---|---|---
# 1  | 22  | MY | No  | Reduced | None | 0 | 0 |
# 2  | 71  | MY | Yes | Normal  | Hard | 1 | 0 |
# 3  | 41  | HY | No  | Reduced | None | 0 | 0 |
# 4  | 32  | MY | Yes | Normal  | Hard | 1 | 0 |
# 5  | 68  | HY | Yes | Reduced | None | 0 | 0 |
# 6  | 72  | MY | No  | Normal  | Soft | 0 | 1 |
# 7  | 62  | HY | Yes | Normal  | None | 0 | 0 |
# 8  | 42  | MY | Yes | Reduced | None | 0 | 0 |
# 9  | 38  | MY | No  | Reduced | None | 0 | 0 |
# 10 | 43  | MY | No  | Normal  | Soft | 0 | 1 |
# 11 | 28  | HY | Yes | Normal  | None | 0 | 0 |
# 12 | 37  | MY | Yes | Normal  | Hard | 1 | 0 |
# 13 | 45  | HY | Yes | Normal  | None | 0 | 0 |
# 14 | 37  | HY | No  | Normal  | Soft | 0 | 1 |
# 15 | 68  | HY | No  | Normal  | Soft | 0 | 1 |
# 16 | 18  | MY | Yes | Reduced | None | 0 | 0 |
# 17 | 51  | MY | No  | Reduced | None | 0 | 0 |
# 18 | 15  | HY | No  | Normal  | Soft | 0 | 1 |
# 19 | 63  | MY | Yes | Reduced | None | 0 | 0 |
# 20 | 30  | MY | No  | Normal  | Soft | 0 | 1 |
# 21 | 74  | HY | No  | Reduced | None | 0 | 0 |
# 22 | 44  | HY | Yes | Reduced | None | 0 | 0 |
# 23 | 15  | HY | No  | Reduced | None | 0 | 0 |
# 24 | 17  | HY | Yes | Reduced | None | 0 | 0 |

# %% [markdown]
# ### F): Determinar a partir de los datos si las siguientes hipotesis son verdaderas o falsas:
#     1. Si el lagrimeo es reducido entonces la recomendación es nada (es decir, no usar lentes de contacto).
#     2. Si la prescripcion es hipermetropia, no tiene astigmatismo y el lagrimeo es normal entonces la recomendación es lentes duras.

# %% [markdown]
# 1. **Si el lagrimeo es reducido entonces la recomendación es nada (es decir, no usar lentes de contacto)**
#
#     Es **Verdadera**, mirando la tabla anterior vemos que en todos los casos en donde una instancia tiene el valor *Reduced* en la columna *Tearing*, los conceptos *HardLenses* y *SoftLenses* tienen el valor 0.
#
#
# 2. **Si la prescripcion es hipermetropia, no tiene astigmatismo y el lagrimeo es normal entonces la recomendación es lentes duras**
#
#     Es **Falsa**, en el décimocuarto ejemplo de entrenamiento tenemos un paciente con esos valores en los atributos y *UseHardLenses* tiene el valor de 0.

# %% [markdown]
# ### G): Elaborar las hipotesis especificas maximales en el aprendizaje de los conceptos: prescripcion de lentes duras y prescripcion de lentes blandas. Ayuda: Reconocer previamente las variables irrelevantes para ambos problemas.

# %% [markdown]
# Se buscan hipotesis $h_{1}$ y $h_{2}$ tal que $h_{1} = HardLenses(x)$ y $ h_{2} = SoftLenses(x)$ para cada $x$ de la muestra de entrenamiento.
#
# Se usa el algoritmo $FIND-S$ que sólo con ejemplos positivos encuentra la hipótesis específica maximal, yendo de la mas específica a la más general que permitan los datos.
#
# 1. Para encontrar $h_{1}$ tomemos primeros los ejemplos de entrenamientos positivos que nos interesan, es decir, aquellos :
#
#     * $x_{1}$ = $<71, MY, Yes, Normal>$
#     * $x_{2}$ = $<32, MY, Yes, Normal>$
#     * $x_{3}$ = $<37, MY, Yes, Normal>$
#
#     Luego se aplica el algoritmo, inicializando $h_{1}$ = $<\emptyset, \emptyset, \emptyset, \emptyset>$ como la hipótesis más específica.
#
#     Tras tomar $x_{1}$, se debe generalizar la hipótesis para que satisfaga este ejemplo y obtenemos $h_{1}$ = $<71, MY, Yes, Normal>$.
#
#     Luego tomamos $x_{2}$, como la edad cambia se debe generalizar la hipótesis y nos queda $h_{1}$ = $< ?, MY, Yes, Normal>$.
#
#     Por último como todas restricciones de atributos en $h_{1}$ son satisfechas por $x_{3}$ entonces no hace falta generalizar.
#
#     Es así que $h_{1}$ = $< ?, MY, Yes, Normal>$ es la hipótesis para el concepto *Prescripción de lentes duras*.
#
#
# 2. Para encontrar $h_{2}$ hacemos los mismo, los ejemplos positivos que nos interesan son:
#
#     * $x_{1}$ = $<72, MY, No, Normal>$
#     * $x_{2}$ = $<43, MY, No, Normal>$
#     * $x_{3}$ = $<37, HY, No, Normal>$
#     * $x_{4}$ = $<68, HY, No, Normal>$
#     * $x_{5}$ = $<15, HY, No, Normal>$
#     * $x_{6}$ = $<30, MY, No, Normal>$
#
#     Luego se aplica el algoritmo, inicializando $h_{2}$ = $<\emptyset, \emptyset, \emptyset, \emptyset>$ como la hipótesis más específica.
#
#     Tras tomar $x_{2}$, se debe generalizar la hipótesis para que satisfaga este ejemplo y obtenemos $h_{2}$ = $<72, MY, No, Normal>$.
#
#     Tomamos $x_{2}$, como la edad cambia se generaliza y nos queda $h_{2}$ = $< ?, MY, No, Normal>$.
#
#     Con $x_{3}$ se debe generalizar el atributo "Prescription" y entonces $h_{2}$ = $< ?, ?, No, Normal>$
#
#     Con los ejemplos restantes $x_{4}$, $x_{5}$ y $x_{6}$, la hipoesis no debe generalizarse más.
#
#     Por lo tanto $h_{2}$ = $< ?, ?, No, Normal>$ es la hipótesis para el concepto *Prescripción de lentes blandas*.

# %% [markdown]
# ### H): Utilizando las hipotesis especıficas elaboradas, construir un arbol de decision utilizando en cada nodo la sentencia if sobre los valores una caracterıstica para reproducir el criterio de clasificacion empleado en el consultorio oftalmologico.
# Ayuda: Las decisiones en cada nodo sobre los valores de las caracteristicas son todas binarias y no se repiten caracteristicas una vez usadas. La construccion de este arbol determina una jerarquia de las caracteristicas en cuanto su importancia en la determinacion de la clase.

# %% [markdown]
# Las hipótesis encontradas fueron:
#  * $h_{1}$ = $< ?, MY, Yes, Normal>$ para el concepto Prescripción de lentes duras.
#  * $h_{2}$ = $< ?, ?, No, Normal>$ para el concepto Prescripción de lentes blandas.
#
# Notamos que ambas tienen en común el valor *Normal* en la variable *Tearing* así que todas las personas que usarán lentes deben cumplir esta condición. Por lo que Lagrimeo sería el primer nodo del árbol, separando a los que pueden usar lentes de los que no.
#
# Después vemos que las personas que usan lentes duras tienen astigmastimo y miopia y las personas que usan lentes blandas no tienen astigmatismo y pueden tener cualquiera de las patologías. Esto nos dice que el criterio se seleccion es la presencia de astigmatismo: no tener astigamatismo implica usar lentes blandas y tieniendo astigmatismo se tiene que verificar el tipo de patología para elegir lentas duras sólo para los que tengan miopía.
#
# El árbol de decisión inferido nos queda asi:
#
# ![decision_tree_1](images/decision_tree_1.png)

# %% [markdown]
# ### Ejercicio 2: Se desea inferir el método de elección de libros de lectura. Para ello se estudian los siguientes variables

# %% [raw]
# ________________________________________
#
#     Libro      (número de identificación)
#
#     Acción     (leer-no leer)
#
#     Autor        (conocido-desconocido)
#
#     Trama       (nueva-vieja)
#
#     Longitud    (largo-corto)
#
#     Sitio        (casa-trabajo)
#
# _______________________________________

# %% [markdown]
# Y se recolectan los siguientes datos.

# %% [raw]
#      |  Ejemplo | Accion  | Autor       | Trama | Longitud | Sitio  |
#     -----------------------------------------------------------------
#      |e1        |saltar   |conocido     |nuevo  |largo     |casa    |
#      |e2        |leer     |desconocido  |nuevo  |corto     |trabajo |
#      |e3        |saltar   |desconocido  |viejo  |largo     |trabajo |
#      |e4        |saltar   |conocido     |viejo  |largo     |casa    |
#      |e5        |leer     |conocido     |nuevo  |corto     |casa    |
#      |e6        |saltar   |conocido     |viejo  |largo     |trabajo |
#      |e7        |saltar   |desconocido  |viejo  |corto     |trabajo |
#      |e8        |leer     |desconocido  |nuevo  |corto     |trabajo |
#      |e9        |saltar   |conocido     |viejo  |largo     |casa    |
#      |e10       |saltar   |conocido     |nuevo  |largo     |trabajo |
#      |e11       |saltar   |desconocido  |viejo  |corto     |casa    |
#      |e12       |saltar   |conocido     |nuevo  |largo     |trabajo |
#      |e13       |leer     |conocido     |viejo  |corto     |casa    |
#      |e14       |leer     |conocido     |nuevo  |corto     |trabajo |
#      |e15       |leer     |conocido     |nuevo  |corto     |casa    |
#      |e16       |leer     |conocido     |viejo  |corto     |trabajo |
#      |e17       |leer     |conocido     |nuevo  |corto     |casa    |
#      |e18       |leer     |desconocido  |nuevo  |corto     |trabajo |

# %% [markdown]
# ### A): A partir de la informacion disponible, elabore un dataframe adecuado para minería. Identifique las caracteristicas (variables) y su tipo de datos y declare cual es la clase y sus valores para el problema de clasificacion.

# %% [markdown]
# La tabla deberá incluir las siguientes columnas:
#
# |  Column name  | Description | Value Type |
# |---         |---       |---
# | **Author** | Knowledge of the author of the book | String, "Known"/Unknown" |
# | **Plot** | Plot of the book | String, "New"/"Old"|
# | **Length** | Length of the book | String, "Long"/"Short" |
# | **Place** |  The place where to read the book | String, "Work"/"Home" |
# |**Recomedation**| If we must skip or read the book | String, "Skip"/"Read" |
# | **ReadBook**| If the person must read the book |  Numerical,  0/1 |
#
# El concepto que nos interesa aprender es el *ReadBook*. Queremos saber si dada la popularidad del autor, el tipo de trama, el tiempo de lectura y el lugar en donde se leerá, conviene leerlo o no.
#
# Para la establecer el valor del concepto usamos la siguiente regla:
#
# $ReadBook(x) = 1 $ if *Recomendation = Read* else $0$.
#
# Con esto el dataframe nos quedaría:
#
# |**# example**|**Author**|  **Plot**  | **Length** | **Place** | **Recomendation** | **ReadBook** |
# |---|---|---|---|---|---|---
# | 1 |Known   | New  | Long  | Home | Skip | 0
# | 2 |Unknown | New  | Short | Work | Read | 1
# | 3 |Unknown | Old  | Long  | Work | Skip | 0
# | 4 |Known   | Old  | Long  | Home | Skip | 0
# | 5 |Known   | New  | Short | Home | Read | 1
# | 6 |Known   | Old  | Long  | Work | Skip | 0
# | 7 |Unknown | Old  | Short | Work | Skip | 0
# | 8 |Unknown | New  | Short | Work | Read | 1
# | 9 |Known   | Old  | Long  | Home | Skip | 0
# | 10|Known   | New  | Long  | Work | Skip | 0
# | 11|Unknown | Old  | Short | Home | Skip | 0
# | 12|Known   | New  | Long  | Work | Skip | 0
# | 13|Known   | Old  | Short | Home | Read | 1
# | 14|Known   | New  | Short | Work | Read | 1
# | 15|Known   | New  | Short | Home | Read | 1
# | 16|Known   | Old  | Short | Work | Read | 1
# | 17|Known   | New  | Short | Home | Read | 1
# | 18|Unknown | New  | Short | Work | Read | 1

# %% [markdown]
# ### B): Calcule el numero total de instancias posibles.

# %% [markdown]
# Todos los atributos (*autor*, *trama*, *longitud*, *sitio*) tienen 2 valores posibles cada uno; si agregamos el símbolo $?$ para cada atributo y luego contamos la posible existencia del símbolo para algún atributo $\emptyset$, entonces tendremos un total de $1 + (3 \times 3 \times 3 \times 3) = 82$ instancias posibles.

# %% [markdown]
# ### C): Determinar a partir de los datos si las siguientes hipotesis son verdaderas o falsas:
#     1. Si el el libro es de un autor conocido con una trama vieja, es corto y se desea leer camino al trabajo, la recomendación es no leer.
#     2. Si el el libro es de un autor desconocido con una trama nueva, es corto y se desea leer
#     camino al trabajo, la recomendación es leer.

# %% [markdown]
# 1. **Si el el libro es de un autor conocido con una trama vieja, es corto y se desea leer camino al trabajo, la recomendación es no leer.**
#
#     Es **Falso**, mirando el dataframe hay un ejemplo de entrenamiento (el único, el décimosexto) que cumple con las restricciones y tiene como recomendación *Read*.
#
#
# 2. **Si el el libro es de un autor desconocido con una trama nueva, es corto y se desea leer camino al trabajo, la recomendación es leer**.
#
#     Es **Verdadero**, los únicos tres ejemplos de entrenamiento (2º, 8º y 18º) de entrenamiento que tienen estas restricciones tienen como recomendación *Read*.

# %% [markdown]
# ### D): Elaborar las hipotesis especificas maximales en el aprendizaje del concepto 'recomendacion para leer'.

# %% [markdown]
# Se busca la hipotesis $h$ que cumpla que $h$ = $ReadBook(x)$ para cada instancia x de la muestra de entrenamiento.
#
# Se usa el algoritmo  𝐹𝐼𝑁𝐷−𝑆  que sólo con ejemplos positivos encuentra la hipótesis específica maximal, yendo de la mas específica a la más general que permitan los datos.
#
# Los ejemplos positivos que nos interesan son los siguientes:
#
# * $x_{2}$ = $<Unknown, New, Short, Work >$
# * $x_{5}$ = $<Known, New, Short, Home >$
# * $x_{8}$ = $<Unknown, New, Short, Work >$
# * $x_{13}$ = $<Known, Old, Short, Home >$
# * $x_{14}$ = $<Known, New, Short, Work >$
# * $x_{15}$ = $<Known, New, Short, Home >$
# * $x_{16}$ = $<Known, Old, Short, Work >$
# * $x_{17}$ = $<Known, New, Short, Home >$
# * $x_{18}$ = $<Unknown, New, Short, Work >$
#
# Luego se aplica el algoritmo, inicializando $h$ = $<\emptyset, \emptyset, \emptyset, \emptyset>$ como la hipótesis más específica.
#
# Tras tomar $x_{2}$, se debe generalizar la hipótesis para que satisfaga este ejemplo y obtenemos $h$ = $<Unknown, New, Short, Work>$.
#
# Con el siguiente ejemplo $x_{5}$ se generaliza para obtener $h$ = $< ?, New, Short, ? >$.
# Con el que sigue $x_{8}$ no hace falta generalizar y la hipótesis permanece igual.
#
# Con $x_{13}$ debemos generalizar de nuevo y nos queda $h$ = $< ?, ? , Short, ? >$.
#
# Tomandos los ejemplos restantes $x_{14}$, $x_{15}$, $x_{16}$, $x_{17}$ y $x_{18}$ vemos que no hace falta generalizar más y la hipóteis para el concepto *Recomendación para leer* es $h$ = $< ?, ? , Short, ? >$.

# %% [markdown]
# ### E): Utilizando las hipotesis especıficas elaboradas, construir un arbol de decision utilizando en cada nodo la sentencia if sobre los valores una caracterıstica para reproducir el criterio de clasificacion empleado.

# %% [markdown]
# Al mirar la hipotesis obtenida para el concepto *Recomendacion para leer* vemos que importa solo la característica *Longitud*. Según esto todos los libros que se son recomendados para leer tienen que ser cortos; los largos no deben leerse, por lo tanto el árbol de decisión es muy simple:
#
# ![decision_tree_1](images/decision_tree_2.png)
#
# Sin embargo, aplicando el árbol a los ejemplos del conjunto de entrenamiento se observa que dos ejemplos (el 7º y 11º) son clasificados como recomendados para leer cuando no lo fueron en realidad.

# %% [markdown]
# <br>
# <br>
